# %%
#import the useful libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Read the data set of "Marketing Analysis" in data.
df= pd.read_csv("laliga21-22.csv")

# Printing the data
df
# Out:
#     Unnamed: 0            Squad  MP   W   D   L    GF    GA  GD  Pts  ...  \
# 0            0      Real Madrid  38  26   8   4  80.0  31.0  49   86  ...
# 1            1        Barcelona  38  21  10   7  68.0  38.0  30   73  ...
# 2            2  Atlético Madrid  38  21   8   9  65.0  43.0  22   71  ...
# 3            3          Sevilla  38  18  16   4  53.0  30.0  23   70  ...
# 4            4            Betis  38  19   8  11  62.0  40.0  22   65  ...
# 5            5    Real Sociedad  38  17  11  10  40.0  37.0   3   62  ...
# 6            6       Villarreal  38  16  11  11  63.0  37.0  26   59  ...
# 7            7         Valencia  38  11  15  12  48.0  53.0  -5   48  ...
# 8            8          Osasuna  38  12  11  15  37.0  51.0 -14   47  ...
# 9            9       Celta Vigo  38  12  10  16  43.0  43.0   0   46  ...
# 10          10   Rayo Vallecano  38  11   9  18  39.0  50.0 -11   42  ...
# 11          11            Elche  38  11   9  18  40.0  52.0 -12   42  ...
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)
df.head()
# Out:
#              Squad  MP   W   D   L    GF    GA  GD  Pts  Pts/MP  ...  XA90  \
# 0      Real Madrid  38  26   8   4  80.0  31.0  49   86    2.26  ...  1.35
# 1        Barcelona  38  21  10   7  68.0  38.0  30   73    1.92  ...  1.17
# 2  Atlético Madrid  38  21   8   9  65.0  43.0  22   71    1.87  ...  1.00
# 3          Sevilla  38  18  16   4  53.0  30.0  23   70    1.84  ...  0.87
# 4            Betis  38  19   8  11  62.0  40.0  22   65    1.71  ...  1.00
#
#    Save per  Pen save per  shots per  pass completion  prog dist  fouls  \
# 0      77.2          40.0       36.8             87.7   114406.0  460.0
# 1      71.0          33.3       34.2             86.6   119379.0  555.0
# 2      62.5          12.5       32.7             79.8    97041.0  534.0
# 3      76.3          33.3       32.6             83.4   108546.0  531.0
# 4      70.9           0.0       35.3             81.5   100328.0  548.0
#
#    fouls drawn  offsides  aerial per
# 0        557.0     106.0        54.4
# ...

# %%
df.isnull().sum()
# Out:
# Squad                 0
# MP                    0
# W                     0
# D                     0
# L                     0
# GF                    0
# GA                    0
# GD                    0
# Pts                   0
# Pts/MP                0
# xG                    0
# xGA                   0
# xGD                   0
# xGD/90                0
# Attendance percent    0
# gsts                  0
# NDF                   0
# age                   0
# poss                  0
# NPG                   0
# YC                    0
# RC                    0
# GP90                  0
# XG90                  0
# XA90                  0
# Save per              0
# Pen save per          0
# shots per             0
# pass completion       0
# prog dist             0
# fouls                 0
# fouls drawn           0
# offsides              0
# aerial per            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Squad               19 non-null     object
#  1   MP                  19 non-null     int64
#  2   W                   19 non-null     int64
#  3   D                   19 non-null     int64
#  4   L                   19 non-null     int64
#  5   GF                  19 non-null     float64
#  6   GA                  19 non-null     float64
#  7   GD                  19 non-null     int64
#  8   Pts                 19 non-null     int64
#  9   Pts/MP              19 non-null     float64
#  10  xG                  19 non-null     float64
#  11  xGA                 19 non-null     float64
#  12  xGD                 19 non-null     float64
#  13  xGD/90              19 non-null     float64
#  14  Attendance percent  19 non-null     float64
# ...

# %%
df.xGA.describe()
# Out:
# count    19.000000
# mean     47.405263
# std       8.065942
# min      33.700000
# 25%      42.000000
# 50%      46.700000
# 75%      52.450000
# max      61.400000
# Name: xGA, dtype: float64

# %%
plt.scatter(df.Pts,df.xGA)
plt.xlabel("Points")
plt.ylabel("xGA")
plt.show()

# %%
df.plot.scatter(x="xGD",y="RC")
plt.xlabel("xGD")
plt.ylabel("RC")
plt.show()

# %%
sns.pairplot(data = df, vars=['gsts','XG90','GP90'])
plt.show()

# %%
df[['xGA','poss','shots per']].corr()
# Out:
#                 xGA      poss  shots per
# xGA        1.000000 -0.515382  -0.160980
# poss      -0.515382  1.000000   0.695575
# shots per -0.160980  0.695575   1.000000

# %%
sns.heatmap(df[['xGA','poss','shots per']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
df.groupby('Squad')['xG'].mean()
# Out:
# Squad
# Alavés             36.9
# Atlético Madrid    52.8
# Barcelona          62.1
# Betis              55.2
# Celta Vigo         44.0
# Cádiz              41.4
# Elche              34.8
# Espanyol           37.8
# Getafe             29.5
# Granada            41.3
# Levante            56.5
# Mallorca           40.1
# Osasuna            37.2
# Rayo Vallecano     45.4
# Real Madrid        74.4
# Real Sociedad      53.8
# Sevilla            43.5
# Valencia           39.2
# Villarreal         62.6
# Name: xG, dtype: float64

# %%
df.groupby('Squad')['XA90'].mean().plot.bar()
plt.xlabel("Team")
plt.ylabel("xA90")
plt.show()
